# %%
import pandas as pd
rock = pd.read_csv('/Users/Stav/github-repos/Stav-Grossfeld-DSI/week-02/2.4-lab/assets/datasets/rock.csv')

# %%
rock = pd.read_csv('/Users/Stav/github-repos/Stav-Grossfeld-DSI/week-02/2.4-lab/assets/datasets/rock.csv')

import string

print(string.ascii_lowercase)
rock.columns = [
    ''.join([
            y for y in x.lower() 
            if y in string.ascii_lowercase+' '
        ]).replace(' ','_') 
    for x in rock.columns
]
rock
# Out:
# abcdefghijklmnopqrstuvwxyz
#                                        song_clean   artist_clean release_year  \
# 0                                Caught Up in You    .38 Special         1982
# 1                                    Fantasy Girl    .38 Special          NaN
# 2                                 Hold On Loosely    .38 Special         1981
# 3                          Rockin' Into the Night    .38 Special         1980
# 4                               Art For Arts Sake           10cc         1975
# 5                                      Kryptonite   3 Doors Down         2000
# 6                                           Loser   3 Doors Down         2000
# 7                                   When I'm Gone   3 Doors Down         2002
# 8                                      What's Up?  4 Non Blondes         1992
# 9                                      Take On Me           a-ha         1985
# 10                          Baby, Please Don't Go          AC/DC          NaN
# ...

# %%
rock.describe()
# Out:
#         first         year    playcount           fg
# count  2230.0  2230.000000  2230.000000  2230.000000
# mean      1.0     0.741256    16.872646    15.048430
# std       0.0     0.438043    25.302972    25.288366
# min       1.0     0.000000     0.000000     0.000000
# 25%       1.0     0.000000     1.000000     0.000000
# 50%       1.0     1.000000     4.000000     3.000000
# 75%       1.0     1.000000    21.000000    18.000000
# max       1.0     1.000000   142.000000   142.000000

# %%
rock.playcount.value_counts()
# Out:
# 1      619
# 2      236
# 3      147
# 4      123
# 5       81
# 6       52
# 10      47
# 8       46
# 7       39
# 11      32
# 14      30
# 17      28
# 12      27
# 9       25
# 18      24
# 13      23
# 16      22
# 21      21
# 15      20
# 23      20
# 24      18
# 25      18
# 22      16
# 26      16
# 31      16
# 20      15
# 19      15
# 35      14
# 27      13
# 39      12
#       ...
# 97       3
# 76       3
# 106      3
# 80       3
# 102      3
# 113      3
# 94       3
# 141      2
# 0        2
# 66       2
# 99       2
# 78       2
# 119      2
# 109      2
# 134      2
# 68       2
# 67       2
# 121      1
# 115      1
# 111      1
# 107      1
# 125      1
# 95       1
# 138      1
# 132      1
# 120      1
# 116      1
# 110      1
# 100      1
# 142      1
# Name: playcount, dtype: int64
